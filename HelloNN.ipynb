# %% [markdown]
# <a href="https://colab.research.google.com/github/ALJEBORI/Coursera-week6/blob/master/HelloNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Prepare the environment
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
#Preparing your data 
xs=np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
ys=np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

# %%
# Define your ANN model
model=tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])

# %%
#Setting up the losse and optimization functions
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
# Training your created model
model.fit(xs,ys,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6785e-09
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6456e-09
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6112e-09
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5793e-09
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5554e-09
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5162e-09
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4843e-09
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4537e-09
# Epoch 9/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4287e-09
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3959e-09
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3650e-09
# Epoch 12/500
# ...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Testing trained model for different values of x
print('Prediction for the input xs=10',model.predict([10.0]))
print('Prediction for the input xs=7',model.predict([7.0]))
print('Prediction for the input xs=-6',model.predict([-6.0]))
# Out:
# Prediction for the input xs=10 [[18.999878]]
# Prediction for the input xs=7 [[12.999931]]
# Prediction for the input xs=-6 [[-12.999841]]
